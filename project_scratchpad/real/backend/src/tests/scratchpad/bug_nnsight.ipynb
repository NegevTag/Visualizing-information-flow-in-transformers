# %%
import nnsight

from info_flow.config import Config
def get_model(model_name: str, hf_token: str) -> nnsight.LanguageModel:
    model_kwargs_dict = {"token": hf_token}
    return nnsight.LanguageModel(model_name, **model_kwargs_dict)  # type: ignore[arg-type]

config = Config()
model = get_model(model_name="meta-llama/Llama-3.1-8B",hf_token=config.hf_token)
with model.trace("this is a test",remote = True):
    print("a")
# Out:
# <pre style="margin:0;font-family:monospace;background:transparent;"><span style="opacity:0.7">⠹</span> <span style="opacity:0.7">[73f12b7a-f128-41c9-b0f7-8791260147cd]</span> <span style="color:#3498db"><span style="font-weight:bold">RUNNING   </span></span> <span style="opacity:0.7">(0.0s)</span> <span style="opacity:0.7">Your job has started running.</span></pre>
# <pre style="margin:0;font-family:monospace;background:transparent;"><span style="opacity:0.7">ℹ</span> <span style="opacity:0.7">[73f12b7a-f128-41c9-b0f7-8791260147cd]</span> <span style="opacity:0.7"><span style="font-weight:bold">LOG       </span></span> a</pre>
# <pre style="margin:0;font-family:monospace;background:transparent;"><span style="opacity:0.7">⠼</span> <span style="opacity:0.7">[73f12b7a-f128-41c9-b0f7-8791260147cd]</span> <span style="color:#3498db"><span style="font-weight:bold">RUNNING   </span></span> <span style="opacity:0.7">(0.2s)</span> <span style="opacity:0.7">Your job has started running.</span></pre>
# <pre style="margin:0;font-family:monospace;background:transparent;"><span style="color:#2ecc71">✓</span> <span style="opacity:0.7">[73f12b7a-f128-41c9-b0f7-8791260147cd]</span> <span style="color:#2ecc71"><span style="font-weight:bold">COMPLETED </span></span> <span style="opacity:0.7">(0.3s)</span> <span style="opacity:0.7">Your job has been completed.</span></pre>
# ⬇ Downloading:   0%|          | 0.00/341 [00:00<?]
